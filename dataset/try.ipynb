# %%
# from lib2to3.pgen2 import driver
# from selenium import webdriver
# import os
# import time

# fileName = 'output'
# driver=webdriver.Firefox(executable_path=".\geckodriver.exe")
# driver.get('file://{0}/{1}'.format(os.getcwd(), fileName+'.html'))
# time.sleep(5)
# driver.save_screenshot(fileName+'.png')
# driver.quit()

# 00,00,60,00

import cv2
import numpy as np
import matplotlib.pyplot as plt

fileName="clouds.png"
img = cv2.imread(fileName)
img1=img[0:841,60:1530]
cv2.imwrite("clouds1.png",img1)
# plt.imshow(img)
# plt.axis('off')
# plt.show()
# cv2.imshow("new",img1)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# plt.axis('off')
# plt.savefig("clouds1.png")
# plt.show()
# Out:
# True
